# %% [markdown]
# # Python if else – statement Exercise:
#
# Q1. Write a program to calculate the electricity bill
# using only if statement? (accept number of unit from user)
# according to the following criteria:
#
# Unit Price
# First 100 units no charge
# Next 100 units Rs 5 per unit
# After 200 units Rs 10 per unit
# (For example, if input unit is 350 than total bill amount is Rs2000). Lets explain...
# For first 100 no charges
# Now you have 250 unit remaining
# 100-200 you need to pay – 100*5 = 500
# Now 200-100 you need to pay 150*10 = 1500
# Total = 500+1500 = 2000
#
# Q2. Write a program to accept percentage from the user and display
# the grade according to the following criteria:
#
# Marks Grade
# > 90 A
# > 80 and <= 90 B
# >= 60 and <= 80 C
# below 60 D
#
# Q3. Accept the age of 4 people and display the youngest one?
#
# Q4. A company decided to give bonus to employee
# according to following criteria:
#
# Time period of Service Bonus
#
# More than 10 years 10%
#
# >=6 and <=10 8%
#
# Less than 6 years 5%
#
# Ask user for their salary and years of service and print the
# net bonus amount?
#
# Q5. Accept three numbers from the user and
# display the second largest number?
#
# Q6. Accept the marked price from the user and calculate
# the Net amount as (Marked Price – Discount) to pay
# according to following criteria:
#
# Marked Price Discount
# >10000 20%
# >7000 and <=10000 15%
# >
# <=7000 10%
#
# Q7. Accept the marks of English, Math and Science,
# Social Studies Subject and display the stream allotted
# according to following:
#
# All Subjects more than 80 marks — Science Stream
#
# English >80 and Math, Science above 50 — Commerce Stream
#
# English > 80 and social studies > 80 — Humanities
#
# Q8. Write a program to display "Hello" if a number entered
# by user is a multiple of five, otherwise print "Bye"?
#
# Q9. Write a program to check whether the last digit of a number
# (entered by user) is divisible by 3 or not?
#
# Q10. Write a program to check whether a number entered
# is three-digit number or not?

# %% [markdown]
# # 1.

# %%
elec_unit = int(input("Enter the electricity unit:"))
if 100 >= elec_unit:
    print(" No charge")
if 100 < elec_unit and 200 >= elec_unit:
    
    bill = (elec_unit-100)*5
    print("your amount is:",bill)
if 200 < elec_unit :
    
    bill = (100*5) + (elec_unit-200)*10
    print(bill)
# Out:
# Enter the electricity unit: 350
# 2000

# %% [markdown]
# # 2.

# %%
grade = int(input(" Enter the grade :"))
if grade > 90 :
    print(" A grade .")
if grade > 80 and grade <= 90 :
    print(" B grade .")
if grade > 60 and grade <= 80 :
    print(" C grade .")
if grade < 60 :
    print(" D grade")
# Out:
#  Enter the grade : 78
#  C grade .

# %% [markdown]
# # 3.

# %%
a = int(input(" Enter the age of first men : "))
b = int(input(" Enter the age of second men : "))
c = int(input(" Enter the age of third men : "))
d = int(input(" Enter the age of fourth men : "))
if a < b and a < c and a < d :
    print(" A is youngest :")
elif b < a and b < c and b < d :
    print(" B is youngest :")
elif c < a and c < b and a < d :
    print(" C is youngest :") 
else :
    print(" D is youngest")
# Out:
#  Enter the age of first men :  20
#  Enter the age of second men :  24
#  Enter the age of third men :  9
#  Enter the age of fourth men :  5
#  D is youngest

# %% [markdown]
# # 4.

# %%
salary = int(input(" Enter the salary :"))
year = int(input( " Enter the year :"))
netbounsammount = 0
if year > 10 :
    print(" 10% bouns .")
    netbounsammount = salary + (salary * 0.1)
elif salary >= 6 and price <= 10 :
    print(" 8% bouns .")
    netbounsammount = salary + (salary * 0.08)
else  :
    print( " 5 % bouns ")
    netbounsammount = salary + (salary * 0.05)
print(f"final netbounsamount is {netbounsammount} :")
# Out:
#  Enter the salary : 5
#  Enter the year : 5
#  5 % bouns
# final netbounsamount is 5.25 :

# %% [markdown]
# # 5.

# %%
a = int(input(" Enter the first digit : "))
b = int(input(" Enter the second digit : "))
c = int(input(" Enter the third digit : "))

if ( a > b and a < c ) or ( a > c and a < b ):
    print(" second largest is a ")
elif ( b > a and b < c ) or ( b > c and b < a) :
    print(" second largest is b ")
else :
    print ("second largest is c ")
# Out:
#  Enter the first digit :  10
#  Enter the second digit :  20
#  Enter the third digit :  30
#  second largest is b

# %% [markdown]
# # 6.

# %%
price = int(input(" Enter the price :"))
netammount = 0
if price > 10000 :
    print(" 20% discount .")
    netammount = price - (price * 0.2)
elif price > 7000 and price <= 10000 :
    print(" 15% discount .")
    netammount = price - (price * 0.15)
elif price <= 7000 :
    print( " 10 % discount ")
    netammount = price - (price * 0.1)
else:
    print("no discount")
print(f"final price is {netammount} :")
# Out:
#  Enter the price : 15000
#  20% discount .
# final price is 12000.0 :

# %% [markdown]
# # 7.

# %%
english = int(input(" Enter the English marks : "))
math = int(input(" Enter the Math marks : "))
science = int(input(" Enter the Science marks : "))
socialstudies = int(input(" Enter the socialstudies marks : "))
if english > 80 and math > 80 and science > 80 and socialstudies > 80:
    print(" science stream ")
elif english > 80 and math > 50 and science > 50 :
    print(" commerce stream ") 
elif english > 80 and socialstudies > 80:
    print( " humanities ")
else :
    print("no stream alloted")
# Out:
#  Enter the English marks :  85
#  Enter the Math marks :  45
#  Enter the Science marks :  46
#  Enter the socialstudies marks :  90
#  humanities

# %% [markdown]
# # 8.

# %%
num = int(input(" Enter the number :"))
if num % 5 == 0 :
    print(" Hello Word .")
else:
    print(" Bye .")
# Out:
#  Enter the number : 87
#  Bye .

# %% [markdown]
# # 9.

# %%
num = int(input(" Enter the number : "))

if num % 3 == 0 :
    print(" Is divisible .")
else :
    print(" Is not divisble .")
# Out:
#  Enter the number :  145
#  Is not divisble .

# %% [markdown]
# # 10.

# %%
num = int(input(" Enter the number :"))

if num >= 100 and num <= 999 :
    print(" Is three digit number. ") 
else :
    print(" Is no three digit number. ")
# Out:
#  Enter the number : 123
#  Is three digit number.
